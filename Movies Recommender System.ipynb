# %% [markdown]
# # Movies Recommender System

# %% [markdown]
# In this project, we are going to create a program that recommends the 10 mostly rated movies to the user.

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
# load dataset 'ratings.csv'
data = pd.read_csv(r"C:\Users\sanas\Desktop\master\DSC630 datasets\movie reviews dataset\ratings.csv")
# display few rows of this dataset
data.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
# load dataset 'movies.csv'
movie_titles_genre = pd.read_csv(r"C:\Users\sanas\Desktop\master\DSC630 datasets\movie reviews dataset\movies.csv")
# display few rows of this dataset
movie_titles_genre.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %% [markdown]
# ## Recommender Creation

# %%
# merge the two datasets
data = data.merge(movie_titles_genre, on='movieId', how='left')
data.head(20)
# Out:
#     userId  movieId  rating  timestamp  \
# 0        1        1     4.0  964982703
# 1        1        3     4.0  964981247
# 2        1        6     4.0  964982224
# 3        1       47     5.0  964983815
# 4        1       50     5.0  964982931
# 5        1       70     3.0  964982400
# 6        1      101     5.0  964980868
# 7        1      110     4.0  964982176
# 8        1      151     5.0  964984041
# 9        1      157     5.0  964984100
# 10       1      163     5.0  964983650
# 11       1      216     5.0  964981208
# 12       1      223     3.0  964980985
# 13       1      231     5.0  964981179
# 14       1      235     4.0  964980908
# 15       1      260     5.0  964981680
# 16       1      296     3.0  964982967
# 17       1      316     3.0  964982310
# 18       1      333     5.0  964981179
# 19       1      349     4.0  964982563
#
#                                         title  \
# 0                            Toy Story (1995)
# ...

# %%
# calculate the average rating for each movie
Average_ratings = pd.DataFrame(data.groupby('title')['rating'].mean())
# display a few rows of the Average_ratings data frame (constitued from title and rating)
Average_ratings.head(10)
# Out:
#                                            rating
# title
# '71 (2014)                               4.000000
# 'Hellboy': The Seeds of Creation (2004)  4.000000
# 'Round Midnight (1986)                   3.500000
# 'Salem's Lot (2004)                      5.000000
# 'Til There Was You (1997)                4.000000
# 'Tis the Season for Love (2015)          1.500000
# 'burbs, The (1989)                       3.176471
# 'night Mother (1986)                     3.000000
# (500) Days of Summer (2009)              3.666667
# *batteries not included (1987)           3.285714

# %%
# Computing the total ratings for each movie
Average_ratings['Total Ratings'] = pd.DataFrame(data.groupby('title')['rating'].count())
# display a few rows of the data frame
Average_ratings.head(10)
# Out:
#                                            rating  Total Ratings
# title
# '71 (2014)                               4.000000              1
# 'Hellboy': The Seeds of Creation (2004)  4.000000              1
# 'Round Midnight (1986)                   3.500000              2
# 'Salem's Lot (2004)                      5.000000              1
# 'Til There Was You (1997)                4.000000              2
# 'Tis the Season for Love (2015)          1.500000              1
# 'burbs, The (1989)                       3.176471             17
# 'night Mother (1986)                     3.000000              1
# (500) Days of Summer (2009)              3.666667             42
# *batteries not included (1987)           3.285714              7

# %%
#Building The Recommender

# %%
# create a pivot table, where the userId is the index, the columns are movie titles and the values correspond to the rating for each movie by each user.
movie_user = data.pivot_table(index='userId',columns='title',values='rating')
# display a few rows of the pivot table
movie_user.head(20)
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
# 7              NaN                                      NaN
# 8              NaN                                      NaN
# 9              NaN                                      NaN
# 10             NaN                                      NaN
# 11             NaN                                      NaN
# 12             NaN                                      NaN
# 13             NaN                                      NaN
# 14             NaN                                      NaN
# ...

# %%
#Calculating The Correlation between movie titles and movie 'Heat (1995)' based on ratings using the corrwith method.
correlations = movie_user.corrwith(movie_user['Heat (1995)'])
correlations.head()
# Out:
# C:\Users\sanas\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\sanas\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\sanas\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\sanas\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\sanas\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# title
# '71 (2014)                                NaN
# 'Hellboy': The Seeds of Creation (2004)   NaN
# 'Round Midnight (1986)                    NaN
# ...

# %%
# removing the empty rows and merge the 'Total_Ratings' to the correlation table
recommendation = pd.DataFrame(correlations,columns=['Correlation'])
recommendation.dropna(inplace=True)
recommendation = recommendation.join(Average_ratings['Total Ratings'])
recommendation.head()
# Out:
#                                    Correlation  Total Ratings
# title
# 'burbs, The (1989)                   -0.144579             17
# (500) Days of Summer (2009)          -0.449467             42
# ...And Justice for All (1979)         1.000000              3
# 10 Things I Hate About You (1999)     0.166070             54
# 10,000 BC (2008)                      0.612112             17

# %%
# filter all the movies correlated to the Heat movie and have total ratings exceeding 100.
recc = recommendation[recommendation['Total Ratings']>100].sort_values('Correlation',ascending=False).reset_index()

# merge the movies dataset for verifying the recommendations
recc = recc.merge(movie_titles_genre,on='title', how='left')
recc.head(10)
# Out:
#                                                title  Correlation  \
# 0                                        Heat (1995)     1.000000
# 1  Léon: The Professional (a.k.a. The Professiona...     0.651800
# 2                                      Aliens (1986)     0.597448
# 3                                   Inception (2010)     0.565437
# 4                              Reservoir Dogs (1992)     0.535019
# 5                                  Fight Club (1999)     0.524401
# 6                                     Memento (2000)     0.483540
# 7                                    Die Hard (1988)     0.451554
# 8                                   GoldenEye (1995)     0.420222
# 9                              Godfather, The (1972)     0.408204
#
#    Total Ratings  movieId                                           genres
# 0            102        6                            Action|Crime|Thriller
# 1            133      293                      Action|Crime|Drama|Thriller
# ...

# %% [markdown]
# The movie that has the full correlation to Heat movie is Heat movie itself. Leon and Aliens movies have also high correlation with Heat.

# %% [markdown]
# The recommender system and the steps performed:
# - Loading data (ratings and movie titles datasets)
# - Merging the two datasets based on a common column 'movieID'
# - Calculating the average rating and the total rating for each movie
# - Calculating The Correlation between movie titles and the movie selected based on ratings using the corrwith method
# - Merge the Total Ratings to the correlation table
# - filter all the movies correlated to the selected movie and have total ratings exceeding 100.
# - verify the recommendations
# The recommender system recommends these 10 movies to watch to the user based on the correlations with the selected one.
#
# Source: https://analyticsindiamag.com/deep-tech/how-to-build-your-first-recommender-system-using-python-movielens-dataset/
